# %%
Objective of Task 1

The Objective of this Task is to learn how to load, inspect, and visualize a dataset using Python. 
In This Task we can explore basic Data Structure, Summary Stats and Visualizations to understand Patterns, Distributions, and Relationships between Variables.

The Iris dataset contains 150 samples of iris flowers with the following features:

sepal length

sepal width

petal length

petal width

species (Setosa, Versicolor, Virginica)

We will load the dataset using pandas.

Instructions

You must complete the following steps:

1. Load the dataset

Use pandas.read_csv()

Assign column names

Store it in a DataFrame

2. Inspect the dataset

Use the following functions:

.head() → shows the first 5 rows

.shape → number of rows and columns

.columns → column names

.info() → data types and null values

.describe() → summary statistics

3. Visualize the dataset

Using seaborn and matplotlib, create:

✔ Scatter Plot

To visualize relationships between features
(e.g., sepal length vs sepal width)

✔ Histograms

To show the distribution of each feature

✔ Box Plots

To detect outliers or unusual values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")          

# 1. Load Dataset
col_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']  # 5

iris = pd.read_csv(                
    'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
    names=col_names
)

# %%
iris.head()                         

# 2. Dataset Information
print("Shape:", iris.shape)         
print("\nColumns:", iris.columns)   
print("\nInfo:")                    
print(iris.info())                  
print("\nSummary Statistics:")      
print(iris.describe())
# Out:
# Shape: (150, 5)
#
# Columns: Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
# Summary Statistics:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# ...

# %%
# 3. Data Visualization

# Scatter Plot
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species') 
plt.title('Sepal Length vs Sepal Width by Species')                          
plt.show()

# %%
# Histograms
iris.hist(figsize=(10, 8))         
plt.suptitle('Feature Distributions')
plt.show()

# %%
# Boxplot
sns.boxplot(data=iris, orient='h')
plt.title('Boxplot of Iris Features')
plt.show()
